# %%
from urllib.request import urlretrieve
from urllib.request import urlopen

# %%
urlopen('http://google.com')

# %%
url =  'https://www.google.com/images/branding/googlelogo/1x/googlelogo_color_272x92dp.png'

# %%
urllib.request.urlretrieve(url, 'data/logo.png')
print('저장완료')
# Out:
# 저장완료

# %% [markdown]
# # 주피터 노트북 이미지 표시하기

# %% [markdown]
# # 마크다운 셀에서 이미지 확인
#
# ![구글로고](data/logo.png)

# %% [markdown]
# # 명령문 셀에서 이미지 확인

# %%
from IPython.display import Image, HTML

# %%
Image('data/logo.png')

# %%
HTML('<img src = "data/logo.png" alt="google_logo">')
# Out:
# <img src = "data/logo.png" alt="google_logo">

# %% [markdown]
# # BeautifulSoup
# - 파싱을 도와주는 python 라이브러리
# - 정규식을 작성할 필요 없이 tag, id, class 등의 이름으로 쉽게 파싱 가능
# - http://www.crummy.com/software/BeautifulSoup/bs4/doc

# %%
from urllib.request import urlopen

from bs4 import BeautifulSoup as bs

# %%
html = urlopen('https://www.yes24.com')

# %%
print(html)

# %% [markdown]
# # BeautifulSoup 의 파서 기능 이용하기

# %%
bs = bs(html.read(),'html.parser')
bs
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=1170" name="viewport"/>
# <title>YES24 | 대한민국 대표 인터넷서점</title>
# <meta content="YES24 - 대한민국 대표 인터넷서점" name="title"/>
# <meta content="YES24는 대한민국 1위 인터넷 온라인 서점 입니다. 국내 최대의 도서정보를 보유하고 있으며, 음반, DVD, 공연, 영화까지 다양한 문화 콘텐츠 및 서비스를 제공합니다." name="description"/>
# <meta content="인터넷 서점, 온라인 쇼핑, 상품 추천, 쇼핑몰, 상품 검색, 도서 정보, 국내도서, 외국도서, 전자책, eBook, 이북, 크레마, 공연, 콘서트, 뮤지컬, 영화, 음반, 예매, DVD, 블루레이, 예스24, YES24, 교보문고, 알라딘" name="keywords"/>
# <meta content="https://secimage.yes24.com/sysimage/renew/logo_meta.png" property="og:image"/>
# <script src="https://secimage.yes24.com/sysimage/Contents/Scripts/p/jquery/jquery-1.2.6.min.js" type="text/javascript"></script>
# <script src="https://secimage.yes24.com/sysimage/Contents/Scripts/p/jquery/jquery.menu-aim.js?v=20140801" type="text/javascript"></script>
# ...

# %%
type(bs)
# Out:
# bs4.BeautifulSoup

# %% [markdown]
# ## 태그로 찾기 - 도트(.)이용

# %%
bs.h2
# Out:
# <h2 class="yBlind">YES24 카테고리 리스트</h2>

# %%
bs.h2.string
# Out:
# 'YES24 카테고리 리스트'

# %%
bs.dl
# Out:
# <dl id="yesSkip">
# <dt>콘텐츠 바로가기</dt>
# <dd><a href="#yWelTop">본문 바로가기</a></dd>
# </dl>

# %%
bs.dl.dt.string
# Out:
# '콘텐츠 바로가기'

# %%
bs.dl.dd.a
# Out:
# <a href="#yWelTop">본문 바로가기</a>

# %%
bs.ul.li.next_sibling.next_sibling
# Out:
# <li class="cate017"><a href="http://www.yes24.com/Mall/Main/eBook/017?CategoryNumber=017" onclick="setWcode('001_002_003')" title="eBook"><em class="txt">eBook</em></a></li>

# %%
bs.ul.li.next_sibling.next_sibling.a.string
# Out:
# 'eBook'

# %%
bs.img
# Out:
# <img alt="이달의혜택" height="50" src="https://secimage.yes24.com/images/01_Banner/welcome/topBanner/2019/0731_m1_480x50_1.gif" width="480"/>

# %% [markdown]
# # 아이디로 찾기
# ```
# bs.find(id='아이디명')
# ```

# %%
bs.find(id='yHeader')
# Out:
# <h2 class="yBlind">YES24 카테고리 리스트</h2>

# %%
bs.find(id='yWelTopWrap')
# Out:
# <div id="yWelTopWrap">
# <!-- %%%%%%%%%% 카테고리 빅배너 영역 시작 %%%%%%%%%% -->
# <h2 class="yBlind">카테고리 빅배너</h2>
# <ul id="mbnWrap">
# <!-- ********** YES24 NOW 영역 시작 ********** -->
# <li class="mbn_dp1" id="bigbanner_yesnow_area">
# <h3><a class="mTit" data-submenu-id="mbnSub_000" href="javascript:void(0);" onclick="setWcode('004_001_001');">YES NOW</a></h3>
# <div class="mbnSub" id="mbnSub_000" style="display:none">
# <div class="mbnCont yesNowCont">
# <div class="mbnRoll rollCnt4" id="mbnRoll_yNow">
# <!-- 빅배너 YES24 NOW Generator -->
# <div class="mbnRollUnit">
# <div class="yPagen pagen_1">
# <a href="#">
# <em>미피와 ENJOY SUMMER</em>
# </a>
# </div>
# <div class="mCont mbnTp1_1">
# <a href="http://www.yes24.com/campaign/01_book/yesPresent/yesPresent.aspx?EventNo=173214" onclick='setWcode("004_001_001")' target="_self">
# <img alt="미피와 ENJOY SUMMER" border="0" class="lazy" data-original="http://image.yes24.com/images/00_Event/2019/0716miffy/bn_869x421.jpg" height="421" width="869"/>
# ...

# %%
bs.find(id='yWelTopWrap').h2
# Out:
# <h2 class="yBlind">카테고리 빅배너</h2>

# %%
bs.find(id='yWelTopWrap').h2.string
# Out:
# '카테고리 빅배너'

# %%
html = urlopen('http://pythonscraping.com/pages/warandpeace.html')
bs = bs(html.read(),'html.parser')

# %%
bs
# Out:
# []

# %%
html = urlopen('http://pythonscraping.com/pages/warandpeace.html')
print(html)

# %%
bs = bs(html.read(),'html.parser')

# %%
bs
# Out:
# <html>
# <head>
# <style>
# .green{
# 	color:#55ff55;
# }
# .red{
# 	color:#ff5555;
# }
# #text{
# 	width:50%;
# }
# </style>
# </head>
# <body>
# <h1>War and Peace</h1>
# <h2>Chapter 1</h2>
# <div id="text">
# "<span class="red">Well, Prince, so Genoa and Lucca are now just family estates of the
# Buonapartes. But I warn you, if you don't tell me that this means war,
# if you still try to defend the infamies and horrors perpetrated by
# that Antichrist- I really believe he is Antichrist- I will have
# nothing more to do with you and you are no longer my friend, no longer
# my 'faithful slave,' as you call yourself! But how do you do? I see
# I have frightened you- sit down and tell me all the news.</span>"
# <p></p>
# It was in July, 1805, and the speaker was the well-known <span class="green">Anna
# Pavlovna Scherer</span>, maid of honor and favorite of the <span class="green">Empress Marya
# ...

# %%
redList = bs.find_all(class_='red')
len(redList)
# Out:
# 34

# %%
redList[0:3]
# Out:
# [<span class="red">Well, Prince, so Genoa and Lucca are now just family estates of the
#  Buonapartes. But I warn you, if you don't tell me that this means war,
#  if you still try to defend the infamies and horrors perpetrated by
#  that Antichrist- I really believe he is Antichrist- I will have
#  nothing more to do with you and you are no longer my friend, no longer
#  my 'faithful slave,' as you call yourself! But how do you do? I see
#  I have frightened you- sit down and tell me all the news.</span>,
#  <span class="red">If you have nothing better to do, Count [or Prince], and if the
#  prospect of spending an evening with a poor invalid is not too
#  terrible, I shall be very charmed to see you tonight between 7 and 10-
#  Annette Scherer.</span>,
#  <span class="red">Heavens! what a virulent attack!</span>]

# %%
spanList = bs.find_all('span')
len(spanList)
# Out:
# 75

# %%
spanList[-1].string
# Out:
# 'Anna Pavlovna'

# %%
spanSet = set(spanList)

# %%
len(spanSet)
# Out:
# 57

# %%
spanList = list(spanSet)

# %%
pList = bs.find_all('p')
len(pList)
# Out:
# 34

# %%
for i in range(1,6):
    print(spanList[-i].string)
# Out:
# You are
# staying the whole evening, I hope?
# the prince
# What has been decided? They have decided that
# Buonaparte has burnt his boats, and I believe that we are ready to
# burn ours.
# First of all, dear friend, tell me how you are. Set your friend's
# mind at rest,
# Don't joke; I mean to have a serious talk with you. Do you know I
# am dissatisfied with your younger son? Between ourselves

# %%
pList
# Out:
# [<p></p>,
#  <p></p>,
#  <p></p>,
#  <p></p>,
#  <p></p>,
#  <p></p>,
#  <p></p>,
#  <p></p>,
#  <p></p>,
#  <p></p>,
#  <p></p>,
#  <p></p>,
#  <p></p>,
#  <p></p>,
#  <p></p>,
#  <p></p>,
#  <p></p>,
#  <p></p>,
#  <p></p>,
#  <p></p>,
#  <p></p>,
#  <p></p>,
#  <p></p>,
#  <p></p>,
#  <p></p>,
#  <p></p>,
#  <p></p>,
#  <p></p>,
#  <p></p>,
#  <p></p>,
#  <p></p>,
#  <p></p>,
#  <p></p>,
#  <p></p>]

# %%
bs
# Out:
# <html>
# <head>
# <style>
# .green{
# 	color:#55ff55;
# }
# .red{
# 	color:#ff5555;
# }
# #text{
# 	width:50%;
# }
# </style>
# </head>
# <body>
# <h1>War and Peace</h1>
# <h2>Chapter 1</h2>
# <div id="text">
# "<span class="red">Well, Prince, so Genoa and Lucca are now just family estates of the
# Buonapartes. But I warn you, if you don't tell me that this means war,
# if you still try to defend the infamies and horrors perpetrated by
# that Antichrist- I really believe he is Antichrist- I will have
# nothing more to do with you and you are no longer my friend, no longer
# my 'faithful slave,' as you call yourself! But how do you do? I see
# I have frightened you- sit down and tell me all the news.</span>"
# <p></p>
# It was in July, 1805, and the speaker was the well-known <span class="green">Anna
# Pavlovna Scherer</span>, maid of honor and favorite of the <span class="green">Empress Marya
# ...

# %%
spanVar = bs.span
spanVar
# Out:
# <span class="red">Well, Prince, so Genoa and Lucca are now just family estates of the
# Buonapartes. But I warn you, if you don't tell me that this means war,
# if you still try to defend the infamies and horrors perpetrated by
# that Antichrist- I really believe he is Antichrist- I will have
# nothing more to do with you and you are no longer my friend, no longer
# my 'faithful slave,' as you call yourself! But how do you do? I see
# I have frightened you- sit down and tell me all the news.</span>

# %%
spanVar.attrs['class']
# Out:
# ['red']
