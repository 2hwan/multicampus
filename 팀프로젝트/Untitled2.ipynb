# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

import matplotlib.font_manager as fm
path = 'C:\Windows\Fonts\gulim.ttc'
font_name = fm.FontProperties(fname = path).get_name()
print(font_name)
plt.rc('font', family=font_name)

import folium

import seaborn as sns

import warnings
warnings.filterwarnings('ignore')
# Out:
# Gulim

# %%
result = pd.read_excel('teamproject/result.xlsx', encoding='utf-8')
result
# Out:
#        구  대수
# 0    강남구  14
# 1    강서구  14
# 2    서초구  13
# 3    송파구  12
# 4    관악구  12
# 5   영등포구  11
# 6    은평구  11
# 7    노원구   9
# 8    성북구   8
# 9    마포구   8
# 10   구로구   8
# 11  동대문구   8
# 12   중랑구   7
# 13   강북구   7
# 14   양천구   7
# 15   광진구   7
# 16   동작구   6
# 17  서대문구   6
# 18   성동구   6
# 19    중구   5
# 20   도봉구   5
# 21   강동구   5
# 22   용산구   4
# 23   금천구   3
# 24   종로구   3

# %%
result.set_index('구', inplace=True)

# %%
result.plot(kind = 'barh')

# %%
result['대수'].sort_values().plot(kind='barh', grid = True, figsize=(10,10))
result
# Out:
#       대수
# 구
# 강남구   14
# 강서구   14
# 서초구   13
# 송파구   12
# 관악구   12
# 영등포구  11
# 은평구   11
# 노원구    9
# 성북구    8
# 마포구    8
# 구로구    8
# 동대문구   8
# 중랑구    7
# 강북구    7
# 양천구    7
# 광진구    7
# 동작구    6
# 서대문구   6
# 성동구    6
# 중구     5
# 도봉구    5
# 강동구    5
# 용산구    4
# 금천구    3
# 종로구    3
