# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

import matplotlib.font_manager as fm
path = 'C:\Windows\Fonts\gulim.ttc'
font_name = fm.FontProperties(fname = path).get_name()
print(font_name)
plt.rc('font', family=font_name)

import folium

import seaborn as sns

import warnings
warnings.filterwarnings('ignore')
# Out:
# Gulim

# %%
smoke = pd.read_csv('data/smoke.csv', thousands=',', encoding='utf=8')
smoke.head()
# Out:
#    번호   명칭  대분류                주소   규모        설치일     설치주체   운영관리
# 0   1  종로구  개방형          교보빌딩 주차장  37㎡   2016년 9월     교보빌딩   교보빌딩
# 1   2  종로구  개방형          KT본사 주차장  30㎡  2016년 10월      케이티  KT 본사
# 2   3  중 구  개방형            서울시청 옆  48㎡        NaN      서울시     시청
# 3   4  중 구  폐쇄형  을지로입구역 7 8번 출입구간  21㎡   2015년 6월  중구/한국일보   한국일보
# 4   5  중 구  폐쇄형        하나카드본사 측면부  21㎡   2016년 9월  중구/한국일보   한국일보

# %%
import googlemaps

# %%
gmaps_key = 'AIzaSyBZdHkhqeCsxYtE1zjs1LUX718mq-v2jEg'
gmaps = googlemaps.Client(key=gmaps_key)

# %%
smoke['부스주소'] = smoke['명칭'] + ' ' + smoke['주소']
smoke['부스주소'].head()
# Out:
# 0            종로구 교보빌딩 주차장
# 1            종로구 KT본사 주차장
# 2              중 구 서울시청 옆
# 3    중 구 을지로입구역 7 8번 출입구간
# 4          중 구 하나카드본사 측면부
# Name: 부스주소, dtype: object

# %%
sname = []

for name in smoke['부스주소']:
    sname.append(name)
    
sname
# Out:
# ['종로구 교보빌딩 주차장',
#  '종로구 KT본사 주차장',
#  '중 구 서울시청 옆',
#  '중 구 을지로입구역 7 8번 출입구간',
#  '중 구 하나카드본사 측면부',
#  '중 구 하나은행본점 측면부',
#  '중 구 장교빌딩 전면부',
#  '중 구 두산타워 전면부',
#  '중 구 서울역 8번출구',
#  '용산구 서울역 광장 1번출구',
#  '용산구 서울역 광장 3번출구',
#  '성동구 고산자로 270 (구청)',
#  '성동구 왕십리광장(북측)',
#  '성동구 왕십리민자역사 후면',
#  '광진구 동서울터미널',
#  '광진구 건대입구역',
#  '서대문구 서대문구 통일로 87',
#  '서대문구 서대문구 신촌로 197',
#  '서대문구 서대문구 성산로 321',
#  '서대문구 서대문구 충정로 23 ',
#  '서대문구 서대문구 충정로 60',
#  '서대문구 서대문구 충정로 70',
#  '마포구 마포구청',
#  '구로구 동양미래대학교 입구',
#  '서초구 교보타워 주차장 입구',
#  '서초구 양재역 환승주차장 필로티',
#  '서초구 센트럴시티 광장(호남선)',
#  '서초구 고속터미널 광장(경부선 광장 중앙)',
#  '서초구 고속터미널 광장(경부선 건물필로티)',
#  '서초구 서울남부터미널',
#  '서초구 사당역(2~3번 출구)',
#  '강남구 코엑스 아티움 뒷편',
#  '강남구 코엑스 아셈가든내(1)',
#  '강남구 코엑스 아셈가든내(2)',
#  '송파구 가든파이브 영관 앞',
#  '송파구 가든파이브 영관9층 휴게데크 내',
#  '송파구 잠실야구장 외야석 광장',
#  '송파구 잠실야구장 1루 출입구(1) ',
#  '송파구 잠실야구장 1루 출입구(2)',
#  '송파구 잠실야구장 3루 출입구(1)',
#  '송파구 잠실야구장 3루 출입구(2)',
#  '송파구 잠실 롯데월드몰 뒷편(1)',
#  '송파구 잠실 롯데월드몰 뒷편(2)']

# %%
addreess = []
lat = []
lng = []

for name in sname:
    try :
        tmp = gmaps.geocode(name, language='ko')
        addreess.append(tmp[0].get("formatted_address"))

        tmp_loc = tmp[0].get("geometry")

        lat.append(tmp_loc['location']['lat'])
        lng.append(tmp_loc['location']['lng'])

        print(name + '-->' + tmp[0].get("formatted_address"))
    except IndexError:
        pass
# Out:
# 종로구 교보빌딩 주차장-->대한민국 서울특별시 종로구 종로1.2.3.4가동 종로 1
# 종로구 KT본사 주차장-->대한민국 서울특별시 종로구 관철동 45-6
# 중 구 서울시청 옆-->대한민국 서울특별시 중구 명동 세종대로 110
# 중 구 을지로입구역 7 8번 출입구간-->대한민국 서울특별시 중구 을지로동 42 을지로입구
# 중 구 하나카드본사 측면부-->대한민국 서울특별시 중구 다동 140
# 중 구 하나은행본점 측면부-->대한민국 서울특별시 중구 을지로2가 을지로 35
# 중 구 장교빌딩 전면부-->대한민국 서울특별시 중구 장교동 1
# 중 구 두산타워 전면부-->대한민국 서울특별시 중구 광희동 장충단로 275
# 중 구 서울역 8번출구-->대한민국 서울특별시 동작구 남영동 여성프라자 서울역
# 용산구 서울역 광장 1번출구-->대한민국 서울특별시 중구 남영동 한강대로 405
# 용산구 서울역 광장 3번출구-->대한민국 서울특별시 동작구 남영동 여성프라자 서울역
# 성동구 고산자로 270 (구청)-->대한민국 서울특별시 성동구 행당동 고산자로 270
# 성동구 왕십리광장(북측)-->대한민국 서울특별시 행당동 왕십리광장
# 성동구 왕십리민자역사 후면-->대한민국 서울특별시 행당동 왕십리민자역사
# 광진구 동서울터미널-->대한민국 서울특별시 광진구 구의동 546-1
# 광진구 건대입구역-->대한민국 서울특별시 광진구 화양동 102 화양현대아파트 건대입구
# 서대문구 서대문구 통일로 87-->대한민국 서울특별시 서대문구 충현동 통일로 87
# 서대문구 서대문구 신촌로 197-->대한민국 서울특별시 서대문구 대현동 신촌로 197
# 서대문구 서대문구 성산로 321-->대한민국 서울특별시 서대문구 성산로
# 서대문구 서대문구 충정로 23 -->대한민국 서울특별시 서대문구 충정로3가 충정로 23
# 서대문구 서대문구 충정로 60-->대한민국 서울특별시 서대문구 충현동 충정로 60
# ...

# %%
len(addreess)
# Out:
# 43

# %%
data = {'주소':addreess, '위도':lat, '경도':lng }
saddress = pd.DataFrame(data)
saddress.head()
# Out:
#                                 주소         위도          경도
# 0  대한민국 서울특별시 종로구 종로1.2.3.4가동 종로 1  37.570964  126.977765
# 1          대한민국 서울특별시 종로구 관철동 45-6  37.569562  126.983525
# 2        대한민국 서울특별시 중구 명동 세종대로 110  37.566295  126.977945
# 3      대한민국 서울특별시 중구 을지로동 42 을지로입구  37.566056  126.982662
# 4             대한민국 서울특별시 중구 다동 140  37.567118  126.981108

# %%
saddress.to_csv("teamproject/booth.csv", encoding='cp949', sep=',')

# %%
smoke['명칭'].value_counts()
# Out:
# 송파구     9
# 서초구     7
# 중 구     7
# 서대문구    6
# 강남구     3
# 성동구     3
# 종로구     2
# 광진구     2
# 용산구     2
# 마포구     1
# 구로구     1
# Name: 명칭, dtype: int64

# %%
map = folium.Map(location=[saddress['위도'].mean(), saddress['경도'].mean()], zoom_start=12, tiles='Stamen Toner')

for n in saddress.index:
    
    folium.CircleMarker(
        location=[saddress['위도'][n], saddress['경도'][n]],
        radius=3,
        color= 'blue',
        fill=True,
        fill_color='blue'
    ).add_to(map)


map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import json
geo_path = 'data/skorea_municipalities_geo_simple.json'
geo_json = json.load(open(geo_path, encoding = 'utf-8'))

# %%
#df_cafe_temp = smoke[smoke['명칭'] == '이디야']
df_smoke = pd.DataFrame(smoke['명칭'].value_counts())
df_smoke.columns = ['부스수']
df_smoke
# Out:
#       부스수
# 송파구     9
# 서초구     7
# 중 구     7
# 서대문구    6
# 성동구     3
# 강남구     3
# 종로구     2
# 광진구     2
# 용산구     2
# 마포구     1
# 구로구     1

# %%
df_smoke.index['구'] = 0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-1ff888bb0a67> in <module>
# ----> 1 df_smoke.index['구'] = 0
#
# C:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in __setitem__(self, key, value)
#    3936
#    3937     def __setitem__(self, key, value):
# -> 3938         raise TypeError("Index does not support mutable operations")
#    3939
#    3940     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %%
type(df_smoke)
# Out:
# pandas.core.frame.DataFrame

# %%
map = folium.Map(location=[saddress['위도'].mean(), saddress['경도'].mean()], 
                 zoom_start=11, tiles='Stamen Toner')

map.choropleth(geo_data = geo_json,
               data = df_smoke['부스수'],
               columns = [df_smoke.index, df_smoke['부스수']],
               fill_color = 'PuBu',
               key_on = 'feature.properties.name',
               fill_opacity=0.7,
               line_opacity=0.2,
               highlight=True)


for n in saddress.index:
        folium.CircleMarker(
            location=[saddress.loc[n,'위도'], saddress.loc[n, '경도']],
            radius=3,
            color= 'blue',
            fill=True,
            fill_color='white'
        ).add_to(map)


map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_smoke = pd.read_csv('data/df_smoke.csv', thousands=',', encoding='cp949')
df_smoke.head()
# Out:
#       구  부스수
# 0   송파구    9
# 1    중구    7
# 2   서초구    7
# 3  서대문구    6
# 4   성동구    3

# %%
df_smoke.set_index('구', inplace = True)
df_smoke
# Out:
#       부스수
# 구
# 송파구     9
# 중구      7
# 서초구     7
# 서대문구    6
# 성동구     3
# 강남구     3
# 광진구     2
# 용산구     2
# 종로구     2
# 마포구     1
# 구로구     1
# 강동구     0
# 강북구     0
# 강서구     0
# 관악구     0
# 금천구     0
# 노원구     0
# 도봉구     0
# 동대문구    0
# 동작구     0
# 중랑구     0
# 은평구     0
# 영등포구    0
# 양천구     0
# 성북구     0

# %%
saddress['위도'].mean()
# Out:
# 37.53308695348835

# %%
 saddress['경도'].mean()
# Out:
# 127.01596596511632

# %%
map = folium.Map(location=[saddress['위도'].mean(), saddress['경도'].mean()], 
                 zoom_start=11, tiles='Mapbox Control Room')

map.choropleth(geo_data = geo_json,
               data = df_smoke['부스수'],
               columns = [df_smoke.index, df_smoke['부스수']],
               fill_color = 'PuBu',
               key_on = 'feature.properties.name',
               fill_opacity=0.7,
               line_opacity=0.2,
               highlight=True)


# for n in saddress.index:
#         folium.CircleMarker(
#             location=[saddress.loc[n,'위도'], saddress.loc[n, '경도']],
#             radius=3,
#             color= 'blue',
#             fill=True,
#             fill_color='white'
#         ).add_to(map)


map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 2일차 정리

# %%
booth = pd.read_csv('teamproject/booth.csv', thousands=',', encoding='cp949')
booth
# Out:
#     Unnamed: 0                                     주소         위도          경도
# 0            0        대한민국 서울특별시 종로구 종로1.2.3.4가동 종로 1  37.570964  126.977765
# 1            1                대한민국 서울특별시 종로구 관철동 45-6  37.569562  126.983525
# 2            2              대한민국 서울특별시 중구 명동 세종대로 110  37.566295  126.977945
# 3            3            대한민국 서울특별시 중구 을지로동 42 을지로입구  37.566056  126.982662
# 4            4                   대한민국 서울특별시 중구 다동 140  37.567118  126.981108
# 5            5             대한민국 서울특별시 중구 을지로2가 을지로 35  37.566402  126.981884
# 6            6                    대한민국 서울특별시 중구 장교동 1  37.567118  126.987052
# 7            7             대한민국 서울특별시 중구 광희동 장충단로 275  37.569136  127.009070
# 8            8           대한민국 서울특별시 동작구 남영동 여성프라자 서울역  37.553607  126.969620
# 9            9           대한민국 서울특별시 동작구 남영동 여성프라자 서울역  37.553607  126.969620
# 10          10             대한민국 서울특별시 중구 남영동 한강대로 405  37.554091  126.971526
# ...

# %%
boothnum = pd.read_csv('teamproject/booth_num.csv', thousands=',', encoding='cp949')
boothnum
# Out:
#        구  부스수  부스수2
# 0    송파구    9     9
# 1     중구    7     7
# 2    서초구    7     8
# 3   서대문구    6     6
# 4    성동구    3     3
# 5    강남구    3     4
# 6    광진구    2     2
# 7    용산구    2     3
# 8    종로구    2     2
# 9    마포구    1     6
# 10   구로구    1     1
# 11   강동구    0     0
# 12   강북구    0     0
# 13   강서구    0     1
# 14   관악구    0     0
# 15   금천구    0     0
# 16   노원구    0     2
# 17   도봉구    0     0
# 18  동대문구    0     0
# 19   동작구    0     1
# 20   중랑구    0     0
# 21   은평구    0     0
# 22  영등포구    0     0
# 23   양천구    0    10
# 24   성북구    0     0

# %%
boothnum.set_index('구', inplace = True)
boothnum.head()
# Out:
#       부스수  부스수2
# 구
# 송파구     9     9
# 중구      7     7
# 서초구     7     8
# 서대문구    6     6
# 성동구     3     3

# %%
#02skorea_municipalities_geo_simple
import json
geo_path = 'data/map/skorea-municipalities-2018-geo.json'
geo_json = json.load(open(geo_path, encoding = 'utf-8'))

# %%
map = folium.Map(location=[booth['위도'].mean(), booth['경도'].mean()], zoom_start=12, tiles='Mapbox Control Room')

map.choropleth(geo_data = geo_json,
               data = boothnum['부스수2'],
               columns = [boothnum.index, boothnum['부스수2']],
               fill_color = 'PuBu',
               key_on = 'feature.properties.name',
               fill_opacity=1,
               line_opacity=1,
               highlight=True)

for n in booth.index:    
    folium.CircleMarker(
        location=[booth['위도'][n], booth['경도'][n]],
        radius=10,
        color= 'blue',
        fill=True,
        fill_color='blue'
    ).add_to(map)


map.save('data/map/booth2.html')
