# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

import matplotlib.font_manager as fm
path = 'C:\Windows\Fonts\gulim.ttc'
font_name = fm.FontProperties(fname = path).get_name()
print(font_name)
plt.rc('font', family=font_name)

import folium

import seaborn as sns

import warnings
warnings.filterwarnings('ignore')
# Out:
# Gulim

# %%
minwon = pd.read_csv('teamproject/minwon.csv', thousands=',', encoding='cp949')
minwon.head()
# Out:
#      구     인구수   흡연률   흡연자수  흡연구역   금연구역  단속건수     과태료  직장인의료보험가입자수  단속건수정렬  \
# 0  종로구  162413  19.8  32158   184  10686  2514  251400        52489       3
# 1   중구  136276  25.0  34069   422  12480  4293  364060        46611       4
# 2  용산구  245069  18.8  46073   212   8102   918   91800        81397       1
# 3  성동구  312991  20.4  63850   255   7620  2153  205400       109503       3
# 4  광진구  369470  22.8  84239   158   9982  2384  238400       127871       3
#
#          대수
# 0  3.331934
# 1  4.013939
# 2  3.976571
# 3  5.772510
# 4  7.480239

# %%
minwon.set_index('구', inplace=True)

# %%
minwon.head()
# Out:
#         인구수   흡연률   흡연자수  흡연구역   금연구역  단속건수     과태료  직장인의료보험가입자수  단속건수정렬  \
# 구
# 종로구  162413  19.8  32158   184  10686  2514  251400        52489       3
# 중구   136276  25.0  34069   422  12480  4293  364060        46611       4
# 용산구  245069  18.8  46073   212   8102   918   91800        81397       1
# 성동구  312991  20.4  63850   255   7620  2153  205400       109503       3
# 광진구  369470  22.8  84239   158   9982  2384  238400       127871       3
#
#            대수
# 구
# 종로구  3.331934
# 중구   4.013939
# 용산구  3.976571
# 성동구  5.772510
# 광진구  7.480239

# %%
minwon.sort_values(by='단속건수', ascending= False)
# Out:
#          인구수   흡연률    흡연자수  흡연구역   금연구역   단속건수      과태료  직장인의료보험가입자수  단속건수정렬  \
# 구
# 서초구   435631  16.3   71008   244  16289  57027  3128700       176176       6
# 영등포구  404229  17.2   69527   491  13881  16173  1617300       144237       5
# 노원구   542603  19.5  105808    70  11074  10675   763750       179286       5
# 송파구   686181  16.1  110475   145  16997   6994   683950       248048       4
# 강남구   547602  19.9  108973   205  29565   4328   429050       223122       4
# 중구    136276  25.0   34069   422  12480   4293   364060        46611       4
# 강동구   428547  15.8   67710     5  10963   4174   398400       151360       4
# 양천구   465095  16.7   77671   134   9788   2838   214459       164444       3
# 종로구   162413  19.8   32158   184  10686   2514   251400        52489       3
# 강서구   602230  19.8  119242   453  13883   2441   242700       219620       3
# 광진구   369470  22.8   84239   158   9982   2384   238400       127871       3
# ...

# %%
import json
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
geo_path = 'data/map/skorea-municipalities-2018-geo.json'
geo_str = json.load(open(geo_path, encoding='utf-8'))

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=10, tiles='Mapbox Control Room')

map.choropleth(geo_data = geo_str,
               data = minwon['단속건수정렬'],
               columns = [minwon.index, minwon['단속건수정렬']],
               fill_color = 'PuBu',
               key_on = 'feature.properties.name',
               fill_opacity=1,
               line_opacity=1,
               highlight=True)

map.save('data/map/minwon_set.html')

# %%
minwon.sort_values(by='단속건수', ascending= False)
# Out:
#          인구수   흡연률    흡연자수  흡연구역   금연구역   단속건수      과태료  직장인의료보험가입자수  단속건수정렬  \
# 구
# 서초구   435631  16.3   71008   244  16289  57027  3128700       176176       6
# 영등포구  404229  17.2   69527   491  13881  16173  1617300       144237       5
# 노원구   542603  19.5  105808    70  11074  10675   763750       179286       5
# 송파구   686181  16.1  110475   145  16997   6994   683950       248048       4
# 강남구   547602  19.9  108973   205  29565   4328   429050       223122       4
# 중구    136276  25.0   34069   422  12480   4293   364060        46611       4
# 강동구   428547  15.8   67710     5  10963   4174   398400       151360       4
# 양천구   465095  16.7   77671   134   9788   2838   214459       164444       3
# 종로구   162413  19.8   32158   184  10686   2514   251400        52489       3
# 강서구   602230  19.8  119242   453  13883   2441   242700       219620       3
# 광진구   369470  22.8   84239   158   9982   2384   238400       127871       3
# ...
