# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

import matplotlib.font_manager as fm
path = 'C:\Windows\Fonts\gulim.ttc'
font_name = fm.FontProperties(fname = path).get_name()
print(font_name)
plt.rc('font', family=font_name)

import folium

import seaborn as sns

import warnings
warnings.filterwarnings('ignore')
# Out:
# Gulim

# %%
smoker = pd.read_csv('data/smoker.csv', encoding='utf-8')
smoker.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-2-c69ccdd36ade> in <module>
# ----> 1 smoker = pd.read_csv('data/smoker.csv', encoding='utf-8')
#       2 smoker.head()
#
# C:\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
smoker = pd.read_excel('data/smoker.xlsx', encoding='utf-8')
smoker
# Out:
#        구     인구수   흡연률    흡연자수
# 0    종로구  162413  19.8   32158
# 1     중구  136276  25.0   34069
# 2    용산구  245069  18.8   46073
# 3    성동구  312991  20.4   63850
# 4    광진구  369470  22.8   84239
# 5   동대문구  363101  18.8   68263
# 6    중랑구  405639  22.9   92891
# 7    성북구  452292  20.6   93172
# 8    강북구  319377  25.7   82080
# 9    도봉구  339001  21.1   71529
# 10   노원구  542603  19.5  105808
# 11   은평구  488285  23.3  113770
# 12  서대문구  324304  21.1   68428
# 13   마포구  385985  17.8   68705
# 14   양천구  465095  16.7   77671
# 15   강서구  602230  19.8  119242
# 16   구로구  439328  18.7   82154
# 17   금천구  254061  23.8   60467
# 18  영등포구  404229  17.2   69527
# 19   동작구  412000  18.4   75808
# 20   관악구  519864  23.5  122168
# 21   서초구  435631  16.3   71008
# 22   강남구  547602  19.9  108973
# 23   송파구  686181  16.1  110475
# 24   강동구  428547  15.8   67710

# %%
smoker.set_index('구', inplace = True)
smoker
# Out:
#          인구수   흡연률    흡연자수
# 구
# 종로구   162413  19.8   32158
# 중구    136276  25.0   34069
# 용산구   245069  18.8   46073
# 성동구   312991  20.4   63850
# 광진구   369470  22.8   84239
# 동대문구  363101  18.8   68263
# 중랑구   405639  22.9   92891
# 성북구   452292  20.6   93172
# 강북구   319377  25.7   82080
# 도봉구   339001  21.1   71529
# 노원구   542603  19.5  105808
# 은평구   488285  23.3  113770
# 서대문구  324304  21.1   68428
# 마포구   385985  17.8   68705
# 양천구   465095  16.7   77671
# 강서구   602230  19.8  119242
# 구로구   439328  18.7   82154
# 금천구   254061  23.8   60467
# 영등포구  404229  17.2   69527
# 동작구   412000  18.4   75808
# 관악구   519864  23.5  122168
# 서초구   435631  16.3   71008
# 강남구   547602  19.9  108973
# 송파구   686181  16.1  110475
# 강동구   428547  15.8   67710

# %%
smoker.sort_values(by='인구수', ascending= False)
# Out:
#          인구수   흡연률    흡연자수
# 구
# 송파구   686181  16.1  110475
# 강서구   602230  19.8  119242
# 강남구   547602  19.9  108973
# 노원구   542603  19.5  105808
# 관악구   519864  23.5  122168
# 은평구   488285  23.3  113770
# 양천구   465095  16.7   77671
# 성북구   452292  20.6   93172
# 구로구   439328  18.7   82154
# 서초구   435631  16.3   71008
# 강동구   428547  15.8   67710
# 동작구   412000  18.4   75808
# 중랑구   405639  22.9   92891
# 영등포구  404229  17.2   69527
# 마포구   385985  17.8   68705
# 광진구   369470  22.8   84239
# 동대문구  363101  18.8   68263
# 도봉구   339001  21.1   71529
# 서대문구  324304  21.1   68428
# 강북구   319377  25.7   82080
# 성동구   312991  20.4   63850
# 금천구   254061  23.8   60467
# 용산구   245069  18.8   46073
# 종로구   162413  19.8   32158
# 중구    136276  25.0   34069

# %%
smoker.sort_values(by='흡연자수', ascending= False)
# Out:
#          인구수   흡연률    흡연자수
# 구
# 관악구   519864  23.5  122168
# 강서구   602230  19.8  119242
# 은평구   488285  23.3  113770
# 송파구   686181  16.1  110475
# 강남구   547602  19.9  108973
# 노원구   542603  19.5  105808
# 성북구   452292  20.6   93172
# 중랑구   405639  22.9   92891
# 광진구   369470  22.8   84239
# 구로구   439328  18.7   82154
# 강북구   319377  25.7   82080
# 양천구   465095  16.7   77671
# 동작구   412000  18.4   75808
# 도봉구   339001  21.1   71529
# 서초구   435631  16.3   71008
# 영등포구  404229  17.2   69527
# 마포구   385985  17.8   68705
# 서대문구  324304  21.1   68428
# 동대문구  363101  18.8   68263
# 강동구   428547  15.8   67710
# 성동구   312991  20.4   63850
# 금천구   254061  23.8   60467
# 용산구   245069  18.8   46073
# 중구    136276  25.0   34069
# 종로구   162413  19.8   32158

# %%
import json
geo_path = 'data/skorea_municipalities_geo_simple.json'
geo_json = json.load(open(geo_path, encoding = 'utf-8'))

# %%
map = folium.Map(location=[37.532869959523794, 127.01591000000003], 
                 zoom_start=11, tiles='Mapbox Control Room')

map.choropleth(geo_data = geo_json,
               data = smoker['흡연자수'],
               columns = [smoker.index, smoker['흡연자수']],
               fill_color = 'PuBu',
               key_on = 'feature.properties.name',
               fill_opacity=0.7,
               line_opacity=0.2,
               highlight=True)

map

# %%
smoker.sort_values(by='흡연자수', ascending= False, inplace = True)

# %%
smoker

# %% [markdown]
# ## 2일차 흡연자수

# %%
#02skorea_municipalities_geo_simple
import json
geo_path = 'data/map/skorea-municipalities-2018-geo.json'
geo_json = json.load(open(geo_path, encoding = 'utf-8'))

# %%
map = folium.Map(location=[37.532869959523794, 127.01591000000003], zoom_start=12, tiles='Mapbox Control Room')

map.choropleth(geo_data = geo_json,
               data = smoker['흡연자수'],
               columns = [smoker.index, smoker['흡연자수']],
               fill_color = 'PuBu',
               key_on = 'feature.properties.name',
               fill_opacity=1,
               line_opacity=1,
               highlight=True)


map.save('data/map/smoker.html')
